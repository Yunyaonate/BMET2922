# %% [markdown]
# <a href="https://colab.research.google.com/github/Yunyaonate/BMET2922/blob/main/Model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install tensorflow-gpu

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import tensorflow as tf
import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from keras.models import Model
from keras.layers import Input, Conv2D, LeakyReLU, BatchNormalization, MaxPool2D, Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, UpSampling2D
from tensorflow.keras.models import Model

import glob
import os
import random
# from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import numpy as np
import cv2
# import os

# %%
print(tf.__version__)  # Ensure this is the GPU version
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.15.0
# Num GPUs Available:  1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load and preview the data

# %%
# import matplotlib.pyplot as plt
# import cv2
# import os
# import glob

# Function to load images
def load_images_from_folder(folder, extension, num_images):
    return sorted(glob.glob(os.path.join(folder, f'*{extension}')))[:num_images]

# Define the paths to the directories and number of images
img_dir = '/content/drive/MyDrive/MDHDS/Capstone/Cato_A/img_dir'
ann_dir = '/content/drive/MyDrive/MDHDS/Capstone/Cato_A/ann_dir'
num_images = 12  # The number of images and masks to display

# Load the first 12 original images and masks
original_image_paths = load_images_from_folder(img_dir, '.jpeg', num_images)
mask_image_paths = [path.replace(img_dir, ann_dir).replace('.jpeg', '.png') for path in original_image_paths]

# Set up the matplotlib figure and axes
ncols = 6  # Number of columns (6 images per row)
nrows = 4  # Number of rows (4 rows for original images and 4 rows for masks)
fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 2 * nrows))  # Adjust the figure size as needed

# Display the images in the first 4 rows
for idx, img_path in enumerate(original_image_paths):
    row = idx // ncols  # Determine the row. Integer division floors the result
    col = idx % ncols   # Determine the column
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
    axs[row * 2, col].imshow(img)  # Place the original image in every even row (0, 2, 4, ...)
    axs[row * 2, col].axis('off')  # Hide axes
    axs[row * 2, col].set_title(os.path.basename(img_path))  # Set the title as the file name

# Display the masks in the second 4 rows (rows 1, 3, 5, and 7)
for idx, mask_path in enumerate(mask_image_paths):
    row = idx // ncols  # Determine the row. Integer division floors the result
    col = idx % ncols   # Determine the column
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read the mask
    axs[row * 2 + 1, col].imshow(mask, cmap='gray')  # Place the mask image in every odd row (1, 3, 5, ...)
    axs[row * 2 + 1, col].axis('off')  # Hide axes
    axs[row * 2 + 1, col].set_title(os.path.basename(mask_path))  # Set the title as the file name

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check the path

# %%
# !ls /content/drive/MyDrive/MDHDS/Capstone/Cato_A
# Out:
# ann_dir  img_dir  mask	original  result

# %% [markdown]
# # Data Loader
# ## Spliting the images
#   - Training : Validating : Testing = 8:1:1

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.utils import to_categorical
# import numpy as np
# import cv2
# import os

def load_data(img_dir, mask_dir, img_shape=(256, 256)):
    img_paths = sorted(glob.glob(os.path.join(img_dir, '*.jpeg')))
    mask_paths = sorted(glob.glob(os.path.join(mask_dir, '*.png')))

    images = [cv2.resize(cv2.imread(path), img_shape) for path in img_paths]
    masks = [cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), img_shape) for path in mask_paths]

    # Normalize images
    images = np.array(images).astype('float32') / 255.
    # Ensure masks are in the correct shape and type
    masks = np.array(masks).astype('float32') / 255.
    # Optionally threshold the masks to make sure they are binary
    masks = (masks > 0.5).astype('float32')

    # If necessary, expand the mask dimensions to match the image dimensions
    # Masks should have a shape of (num_samples, height, width, 1)
    masks = np.expand_dims(masks, axis=-1)

    return images, masks

# Paths to your data directories
img_dir = '/content/drive/MyDrive/MDHDS/Capstone/Cato_A/img_dir'
mask_dir = '/content/drive/MyDrive/MDHDS/Capstone/Cato_A/ann_dir'


# Load your dataset
images, masks = load_data(img_dir, mask_dir)

# Split your dataset
x_train, x_temp, y_train, y_temp = train_test_split(images, masks, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# # Create your data generators
# train_datagen = ImageDataGenerator(
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.05,
#     zoom_range=0.05,
#     horizontal_flip=True,
#     fill_mode='nearest'
# )

# val_datagen = ImageDataGenerator()

# # Note: You don't need to use .flow() methods if you've already loaded the data into memory
# train_generator = train_datagen.flow(x_train, y_train, batch_size=1)
# val_generator = val_datagen.flow(x_val, y_val, batch_size=1)

# Now, train_generator and val_generator can be used in your model.fit call
# Check the number of images in each set

print(f"Training images: {len(x_test)}, Validation images: {len(x_val)}, Testing images: {len(y_test)}")
# Out:
# Training images: 4, Validation images: 4, Testing images: 4

# %% [markdown]
# # IoU

# %%
def iou(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=[1,2,3])
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return K.mean(jac)

# %% [markdown]
# # U-Net Architecture

# %%
def unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    # Downsample
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    # Bottom
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    up1 = UpSampling2D(size=(2, 2))(conv2)

    # Upsample
    merge1 = concatenate([conv1, up1], axis=3)
    conv3 = Conv2D(64, 3, activation='relu', padding='same')(merge1)

    # Output layer
    conv4 = Conv2D(1, 1, activation='sigmoid')(conv3)

    model = Model(inputs=inputs, outputs=conv4)

    return model

# %% [markdown]
# ## Compile the model

# %%
from keras import backend as K


unet_model = unet()
unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[iou])

# Print the model summary to check the architecture
unet_model.summary()

# Plotting the model
keras.utils.plot_model(unet_model, show_shapes=True, show_layer_names=True, dpi=60)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 64)         1792      ['input_4[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_12[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_3[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['conv2d_13[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['conv2d_12[0][0]',
#  )                                                                   'up_sampling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 1)          65        ['conv2d_14[0][0]']
#
# ==================================================================================================
# Total params: 186369 (728.00 KB)
# Trainable params: 186369 (728.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Data Augmentation

# %%
data_gen_args = dict(
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

seed = 1
batch_size = 2

# Assume 'x_train' and 'y_train' are your Numpy arrays of images and masks
image_generator = image_datagen.flow(x_train, batch_size=batch_size, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=batch_size, seed=seed)

train_generator = zip(image_generator, mask_generator)

# %%
# from tensorflow.keras.optimizers import Adam
# Model and training details
model_name = "U-Net"
metric_name = "IoU"
batch_size = 2  # Assuming you used this batch size for training
epochs = 100      # Assuming you trained for this many epochs

model = unet()
model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=[iou])
results = model.fit(train_generator, steps_per_epoch=(len(x_train) // batch_size), epochs=100)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 15/15 [==============================] - 2s 48ms/step - loss: 0.2971 - iou: 0.0322
# Epoch 2/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1377 - iou: 0.0730
# Epoch 3/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0538 - iou: 0.0945
# Epoch 4/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0305 - iou: 0.1700
# Epoch 5/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0213 - iou: 0.2111
# Epoch 6/100
# 15/15 [==============================] - 1s 90ms/step - loss: 0.0165 - iou: 0.2668
# Epoch 7/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0139 - iou: 0.3262
# Epoch 8/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0199 - iou: 0.2871
# Epoch 9/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0121 - iou: 0.3700
# Epoch 10/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0096 - iou: 0.4044
# Epoch 11/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0139 - iou: 0.3571
# Epoch 12/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0118 - iou: 0.3903
# Epoch 13/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0118 - iou: 0.4219
# Epoch 14/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0101 - iou: 0.4365
# Epoch 15/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0086 - iou: 0.4827
# Epoch 16/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0104 - iou: 0.4635
# Epoch 17/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0202 - iou: 0.3476
# Epoch 18/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0096 - iou: 0.4533
# Epoch 19/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0114 - iou: 0.4401
# Epoch 20/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0095 - iou: 0.4619
# Epoch 21/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0087 - iou: 0.4718
# Epoch 22/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0079 - iou: 0.5094
# Epoch 23/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.0082 - iou: 0.5180
# Epoch 24/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0083 - iou: 0.5222
# Epoch 25/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0084 - iou: 0.5219
# Epoch 26/100
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0078 - iou: 0.5282
# Epoch 27/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0093 - iou: 0.5134
# Epoch 28/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0092 - iou: 0.4951
# Epoch 29/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0126 - iou: 0.4492
# Epoch 30/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0085 - iou: 0.4945
# Epoch 31/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0089 - iou: 0.4965
# Epoch 32/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0087 - iou: 0.5038
# Epoch 33/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0089 - iou: 0.5041
# Epoch 34/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0116 - iou: 0.4748
# Epoch 35/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0084 - iou: 0.5045
# Epoch 36/100
# 15/15 [==============================] - 1s 61ms/step - loss: 0.0079 - iou: 0.5204
# Epoch 37/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0082 - iou: 0.5260
# Epoch 38/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.0081 - iou: 0.5385
# Epoch 39/100
# 15/15 [==============================] - 1s 76ms/step - loss: 0.0076 - iou: 0.5494
# Epoch 40/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0079 - iou: 0.5392
# Epoch 41/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0084 - iou: 0.5269
# Epoch 42/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0088 - iou: 0.5136
# Epoch 43/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0075 - iou: 0.5388
# Epoch 44/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0073 - iou: 0.5401
# Epoch 45/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0074 - iou: 0.5519
# Epoch 46/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0073 - iou: 0.5588
# Epoch 47/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0074 - iou: 0.5587
# Epoch 48/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0077 - iou: 0.5518
# Epoch 49/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0084 - iou: 0.5345
# Epoch 50/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0078 - iou: 0.5407
# Epoch 51/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0074 - iou: 0.5402
# Epoch 52/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0074 - iou: 0.5549
# Epoch 53/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0075 - iou: 0.5529
# Epoch 54/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0070 - iou: 0.5646
# Epoch 55/100
# 15/15 [==============================] - 1s 76ms/step - loss: 0.0074 - iou: 0.5610
# Epoch 56/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0079 - iou: 0.5454
# Epoch 57/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0070 - iou: 0.5681
# Epoch 58/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0085 - iou: 0.5305
# Epoch 59/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0080 - iou: 0.5342
# Epoch 60/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0072 - iou: 0.5554
# Epoch 61/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0078 - iou: 0.5514
# Epoch 62/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0065 - iou: 0.5642
# Epoch 63/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0072 - iou: 0.5661
# Epoch 64/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0064 - iou: 0.5762
# Epoch 65/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0078 - iou: 0.5609
# Epoch 66/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0071 - iou: 0.5631
# Epoch 67/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0071 - iou: 0.5709
# Epoch 68/100
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0068 - iou: 0.5797
# Epoch 69/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0067 - iou: 0.5835
# Epoch 70/100
# 15/15 [==============================] - 1s 87ms/step - loss: 0.0072 - iou: 0.5705
# Epoch 71/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.0070 - iou: 0.5762
# Epoch 72/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0070 - iou: 0.5796
# Epoch 73/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0068 - iou: 0.5882
# Epoch 74/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0064 - iou: 0.5880
# Epoch 75/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0073 - iou: 0.5804
# Epoch 76/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0076 - iou: 0.5645
# Epoch 77/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0066 - iou: 0.5957
# Epoch 78/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0069 - iou: 0.5921
# Epoch 79/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0070 - iou: 0.5749
# Epoch 80/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0063 - iou: 0.5917
# Epoch 81/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0069 - iou: 0.5808
# Epoch 82/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0074 - iou: 0.5718
# Epoch 83/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0085 - iou: 0.5415
# Epoch 84/100
# 15/15 [==============================] - 1s 66ms/step - loss: 0.0071 - iou: 0.5604
# Epoch 85/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0071 - iou: 0.5737
# Epoch 86/100
# 15/15 [==============================] - 1s 88ms/step - loss: 0.0073 - iou: 0.5643
# Epoch 87/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.0076 - iou: 0.5626
# Epoch 88/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0069 - iou: 0.5793
# Epoch 89/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0063 - iou: 0.5801
# Epoch 90/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0074 - iou: 0.5725
# Epoch 91/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0070 - iou: 0.5839
# Epoch 92/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0073 - iou: 0.5582
# Epoch 93/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0070 - iou: 0.5800
# Epoch 94/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0062 - iou: 0.5963
# Epoch 95/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0070 - iou: 0.5894
# Epoch 96/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0067 - iou: 0.5959
# Epoch 97/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0073 - iou: 0.5744
# Epoch 98/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0062 - iou: 0.5941
# Epoch 99/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0068 - iou: 0.5888
# Epoch 100/100
# 15/15 [==============================] - 1s 80ms/step - loss: 0.0062 - iou: 0.6020

# %% [markdown]
# # Model Training

# %%
checkpoint_path = '/content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5'

# Defining ModelCheckpoint callback to save the best weights
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Defining EarlyStopping callback to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)
# ,callbacks=[checkpoint_callback, early_stopping]

# Model and training details
model_name = "U-Net"
metric_name = "IoU"
batch_size = 2  # Assuming you used this batch size for training
epochs = 100      # Assuming you trained for this many epochs

history = unet_model.fit(x_train, y_train, validation_split=0.1, epochs=epochs, batch_size=batch_size, verbose=1,callbacks=[checkpoint_callback])

# Loading the best weights
unet_model.load_weights(checkpoint_path)
# Out:
# Epoch 1/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.2765 - iou: 0.0346
# Epoch 1: val_loss improved from inf to 0.19664, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 2s 68ms/step - loss: 0.2755 - iou: 0.0416 - val_loss: 0.1966 - val_iou: 0.0999
# Epoch 2/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1401 - iou: 0.0722
# Epoch 2: val_loss improved from 0.19664 to 0.08005, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1362 - iou: 0.0713 - val_loss: 0.0801 - val_iou: 0.0609
# Epoch 3/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0599 - iou: 0.1031
# Epoch 3: val_loss improved from 0.08005 to 0.04213, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0589 - iou: 0.1058 - val_loss: 0.0421 - val_iou: 0.1261
# Epoch 4/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0311 - iou: 0.1391
# Epoch 4: val_loss improved from 0.04213 to 0.02496, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0309 - iou: 0.1393 - val_loss: 0.0250 - val_iou: 0.1861
# Epoch 5/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0203 - iou: 0.2205
# Epoch 5: val_loss improved from 0.02496 to 0.01432, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0203 - iou: 0.2232 - val_loss: 0.0143 - val_iou: 0.2820
# Epoch 6/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0164 - iou: 0.2887
# Epoch 6: val_loss improved from 0.01432 to 0.00973, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0160 - iou: 0.3049 - val_loss: 0.0097 - val_iou: 0.3911
# Epoch 7/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0142 - iou: 0.3267
# Epoch 7: val_loss improved from 0.00973 to 0.00964, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0140 - iou: 0.3242 - val_loss: 0.0096 - val_iou: 0.3801
# Epoch 8/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0098 - iou: 0.4046
# Epoch 8: val_loss improved from 0.00964 to 0.00807, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0102 - iou: 0.3964 - val_loss: 0.0081 - val_iou: 0.4355
# Epoch 9/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0111 - iou: 0.4020
# Epoch 9: val_loss did not improve from 0.00807
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0110 - iou: 0.4048 - val_loss: 0.0131 - val_iou: 0.3861
# Epoch 10/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0197 - iou: 0.3407
# Epoch 10: val_loss did not improve from 0.00807
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0193 - iou: 0.3320 - val_loss: 0.0240 - val_iou: 0.1958
# Epoch 11/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0195 - iou: 0.3634
# Epoch 11: val_loss did not improve from 0.00807
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0191 - iou: 0.3679 - val_loss: 0.0086 - val_iou: 0.4166
# Epoch 12/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0144 - iou: 0.3928
# Epoch 12: val_loss improved from 0.00807 to 0.00789, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0148 - iou: 0.3722 - val_loss: 0.0079 - val_iou: 0.4434
# Epoch 13/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0101 - iou: 0.4144
# Epoch 13: val_loss did not improve from 0.00789
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0099 - iou: 0.4188 - val_loss: 0.0083 - val_iou: 0.4553
# Epoch 14/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0096 - iou: 0.4196
# Epoch 14: val_loss did not improve from 0.00789
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0099 - iou: 0.4122 - val_loss: 0.0081 - val_iou: 0.4624
# Epoch 15/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0092 - iou: 0.4311
# Epoch 15: val_loss improved from 0.00789 to 0.00767, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0092 - iou: 0.4332 - val_loss: 0.0077 - val_iou: 0.4725
# Epoch 16/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0089 - iou: 0.4445
# Epoch 16: val_loss improved from 0.00767 to 0.00738, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0089 - iou: 0.4421 - val_loss: 0.0074 - val_iou: 0.4709
# Epoch 17/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0112 - iou: 0.4182
# Epoch 17: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0111 - iou: 0.4159 - val_loss: 0.0074 - val_iou: 0.4665
# Epoch 18/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0099 - iou: 0.4293
# Epoch 18: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0100 - iou: 0.4208 - val_loss: 0.0081 - val_iou: 0.4413
# Epoch 19/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0093 - iou: 0.4365
# Epoch 19: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0091 - iou: 0.4356 - val_loss: 0.0074 - val_iou: 0.4702
# Epoch 20/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0105 - iou: 0.4163
# Epoch 20: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0109 - iou: 0.4053 - val_loss: 0.0093 - val_iou: 0.4038
# Epoch 21/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0173 - iou: 0.3646
# Epoch 21: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0175 - iou: 0.3568 - val_loss: 0.0122 - val_iou: 0.3329
# Epoch 22/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0126 - iou: 0.3995
# Epoch 22: val_loss did not improve from 0.00738
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0123 - iou: 0.4008 - val_loss: 0.0079 - val_iou: 0.4465
# Epoch 23/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0114 - iou: 0.4286
# Epoch 23: val_loss improved from 0.00738 to 0.00727, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0115 - iou: 0.4296 - val_loss: 0.0073 - val_iou: 0.4746
# Epoch 24/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0124 - iou: 0.4094
# Epoch 24: val_loss improved from 0.00727 to 0.00712, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0121 - iou: 0.4184 - val_loss: 0.0071 - val_iou: 0.4873
# Epoch 25/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0101 - iou: 0.4375
# Epoch 25: val_loss improved from 0.00712 to 0.00704, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0100 - iou: 0.4367 - val_loss: 0.0070 - val_iou: 0.4912
# Epoch 26/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0085 - iou: 0.4464
# Epoch 26: val_loss improved from 0.00704 to 0.00687, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0087 - iou: 0.4449 - val_loss: 0.0069 - val_iou: 0.5057
# Epoch 27/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0085 - iou: 0.4677
# Epoch 27: val_loss improved from 0.00687 to 0.00667, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0086 - iou: 0.4703 - val_loss: 0.0067 - val_iou: 0.5166
# Epoch 28/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0082 - iou: 0.4858
# Epoch 28: val_loss improved from 0.00667 to 0.00624, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0081 - iou: 0.4878 - val_loss: 0.0062 - val_iou: 0.5441
# Epoch 29/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0083 - iou: 0.5003
# Epoch 29: val_loss did not improve from 0.00624
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0082 - iou: 0.4920 - val_loss: 0.0067 - val_iou: 0.5362
# Epoch 30/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0087 - iou: 0.5010
# Epoch 30: val_loss improved from 0.00624 to 0.00621, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0085 - iou: 0.5078 - val_loss: 0.0062 - val_iou: 0.5578
# Epoch 31/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0081 - iou: 0.5093
# Epoch 31: val_loss improved from 0.00621 to 0.00572, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0081 - iou: 0.5150 - val_loss: 0.0057 - val_iou: 0.5867
# Epoch 32/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0075 - iou: 0.5262
# Epoch 32: val_loss improved from 0.00572 to 0.00534, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0075 - iou: 0.5280 - val_loss: 0.0053 - val_iou: 0.6091
# Epoch 33/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0074 - iou: 0.5430
# Epoch 33: val_loss did not improve from 0.00534
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0072 - iou: 0.5486 - val_loss: 0.0058 - val_iou: 0.6052
# Epoch 34/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0077 - iou: 0.5530
# Epoch 34: val_loss did not improve from 0.00534
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0075 - iou: 0.5461 - val_loss: 0.0061 - val_iou: 0.5957
# Epoch 35/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0085 - iou: 0.5235
# Epoch 35: val_loss improved from 0.00534 to 0.00528, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0083 - iou: 0.5268 - val_loss: 0.0053 - val_iou: 0.6284
# Epoch 36/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0079 - iou: 0.5586
# Epoch 36: val_loss did not improve from 0.00528
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0077 - iou: 0.5643 - val_loss: 0.0055 - val_iou: 0.6219
# Epoch 37/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0105 - iou: 0.5006
# Epoch 37: val_loss did not improve from 0.00528
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0104 - iou: 0.5070 - val_loss: 0.0062 - val_iou: 0.5827
# Epoch 38/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0079 - iou: 0.5191
# Epoch 38: val_loss improved from 0.00528 to 0.00520, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0079 - iou: 0.5232 - val_loss: 0.0052 - val_iou: 0.6065
# Epoch 39/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0079 - iou: 0.5312
# Epoch 39: val_loss improved from 0.00520 to 0.00493, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0080 - iou: 0.5306 - val_loss: 0.0049 - val_iou: 0.6277
# Epoch 40/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0078 - iou: 0.5416
# Epoch 40: val_loss did not improve from 0.00493
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0078 - iou: 0.5472 - val_loss: 0.0052 - val_iou: 0.6218
# Epoch 41/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0071 - iou: 0.5653
# Epoch 41: val_loss improved from 0.00493 to 0.00478, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0070 - iou: 0.5687 - val_loss: 0.0048 - val_iou: 0.6460
# Epoch 42/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0072 - iou: 0.5631
# Epoch 42: val_loss improved from 0.00478 to 0.00469, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0072 - iou: 0.5686 - val_loss: 0.0047 - val_iou: 0.6555
# Epoch 43/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0068 - iou: 0.5882
# Epoch 43: val_loss improved from 0.00469 to 0.00456, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0067 - iou: 0.5849 - val_loss: 0.0046 - val_iou: 0.6623
# Epoch 44/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0070 - iou: 0.5826
# Epoch 44: val_loss improved from 0.00456 to 0.00450, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0071 - iou: 0.5850 - val_loss: 0.0045 - val_iou: 0.6686
# Epoch 45/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0064 - iou: 0.5759
# Epoch 45: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0070 - iou: 0.5603 - val_loss: 0.0051 - val_iou: 0.6486
# Epoch 46/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0129 - iou: 0.4843
# Epoch 46: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0126 - iou: 0.4957 - val_loss: 0.0067 - val_iou: 0.6055
# Epoch 47/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0138 - iou: 0.4801
# Epoch 47: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0137 - iou: 0.4618 - val_loss: 0.0090 - val_iou: 0.4951
# Epoch 48/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0117 - iou: 0.4353
# Epoch 48: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0117 - iou: 0.4320 - val_loss: 0.0058 - val_iou: 0.5599
# Epoch 49/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0080 - iou: 0.5019
# Epoch 49: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0078 - iou: 0.5013 - val_loss: 0.0054 - val_iou: 0.5914
# Epoch 50/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0077 - iou: 0.5289
# Epoch 50: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0075 - iou: 0.5331 - val_loss: 0.0052 - val_iou: 0.6103
# Epoch 51/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0068 - iou: 0.5585
# Epoch 51: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0069 - iou: 0.5587 - val_loss: 0.0052 - val_iou: 0.6198
# Epoch 52/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0067 - iou: 0.5725
# Epoch 52: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0068 - iou: 0.5644 - val_loss: 0.0055 - val_iou: 0.6303
# Epoch 53/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0066 - iou: 0.5772
# Epoch 53: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0066 - iou: 0.5806 - val_loss: 0.0048 - val_iou: 0.6369
# Epoch 54/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0063 - iou: 0.5788
# Epoch 54: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0067 - iou: 0.5695 - val_loss: 0.0049 - val_iou: 0.6708
# Epoch 55/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0074 - iou: 0.5898
# Epoch 55: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0073 - iou: 0.5959 - val_loss: 0.0059 - val_iou: 0.6332
# Epoch 56/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0073 - iou: 0.5407
# Epoch 56: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0073 - iou: 0.5465 - val_loss: 0.0049 - val_iou: 0.6579
# Epoch 57/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0082 - iou: 0.5726
# Epoch 57: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0081 - iou: 0.5736 - val_loss: 0.0052 - val_iou: 0.6419
# Epoch 58/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0080 - iou: 0.5443
# Epoch 58: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0079 - iou: 0.5476 - val_loss: 0.0048 - val_iou: 0.6509
# Epoch 59/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0067 - iou: 0.5878
# Epoch 59: val_loss did not improve from 0.00450
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0067 - iou: 0.5869 - val_loss: 0.0049 - val_iou: 0.6446
# Epoch 60/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0066 - iou: 0.5781
# Epoch 60: val_loss improved from 0.00450 to 0.00447, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0065 - iou: 0.5786 - val_loss: 0.0045 - val_iou: 0.6668
# Epoch 61/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0072 - iou: 0.5882
# Epoch 61: val_loss improved from 0.00447 to 0.00433, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0070 - iou: 0.5951 - val_loss: 0.0043 - val_iou: 0.6748
# Epoch 62/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0062 - iou: 0.5980
# Epoch 62: val_loss did not improve from 0.00433
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0062 - iou: 0.5958 - val_loss: 0.0048 - val_iou: 0.6707
# Epoch 63/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0072 - iou: 0.6005
# Epoch 63: val_loss did not improve from 0.00433
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0071 - iou: 0.5995 - val_loss: 0.0046 - val_iou: 0.6825
# Epoch 64/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0073 - iou: 0.5783
# Epoch 64: val_loss did not improve from 0.00433
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0072 - iou: 0.5797 - val_loss: 0.0047 - val_iou: 0.6517
# Epoch 65/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0062 - iou: 0.5958
# Epoch 65: val_loss did not improve from 0.00433
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0061 - iou: 0.5930 - val_loss: 0.0044 - val_iou: 0.6911
# Epoch 66/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0059 - iou: 0.6252
# Epoch 66: val_loss improved from 0.00433 to 0.00411, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0061 - iou: 0.6208 - val_loss: 0.0041 - val_iou: 0.6960
# Epoch 67/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0064 - iou: 0.6008
# Epoch 67: val_loss did not improve from 0.00411
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0068 - iou: 0.5896 - val_loss: 0.0049 - val_iou: 0.6634
# Epoch 68/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0059 - iou: 0.6175
# Epoch 68: val_loss did not improve from 0.00411
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0058 - iou: 0.6191 - val_loss: 0.0043 - val_iou: 0.6832
# Epoch 69/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0057 - iou: 0.6249
# Epoch 69: val_loss did not improve from 0.00411
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0058 - iou: 0.6177 - val_loss: 0.0042 - val_iou: 0.6971
# Epoch 70/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0061 - iou: 0.6208
# Epoch 70: val_loss improved from 0.00411 to 0.00405, saving model to /content/drive/MyDrive/MDHDS/Capstone/Model/u_net_model.h5
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0059 - iou: 0.6264 - val_loss: 0.0040 - val_iou: 0.7014
# Epoch 71/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0061 - iou: 0.6287
# Epoch 71: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0061 - iou: 0.6292 - val_loss: 0.0046 - val_iou: 0.6828
# Epoch 72/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0055 - iou: 0.6341
# Epoch 72: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0056 - iou: 0.6357 - val_loss: 0.0043 - val_iou: 0.7049
# Epoch 73/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0062 - iou: 0.6384
# Epoch 73: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0062 - iou: 0.6416 - val_loss: 0.0081 - val_iou: 0.5791
# Epoch 74/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0065 - iou: 0.6094
# Epoch 74: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0068 - iou: 0.5807 - val_loss: 0.0046 - val_iou: 0.6782
# Epoch 75/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0067 - iou: 0.5958
# Epoch 75: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0065 - iou: 0.6045 - val_loss: 0.0041 - val_iou: 0.6890
# Epoch 76/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0059 - iou: 0.6219
# Epoch 76: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0058 - iou: 0.6271 - val_loss: 0.0043 - val_iou: 0.6927
# Epoch 77/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0059 - iou: 0.6311
# Epoch 77: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0057 - iou: 0.6394 - val_loss: 0.0047 - val_iou: 0.6849
# Epoch 78/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0053 - iou: 0.6570
# Epoch 78: val_loss did not improve from 0.00405
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0054 - iou: 0.6314 - val_loss: 0.0061 - val_iou: 0.6254
# Epoch 79/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0069 - iou: 0.6054
# Epoch 79: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0069 - iou: 0.6077 - val_loss: 0.0051 - val_iou: 0.6713
# Epoch 80/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0060 - iou: 0.6205
# Epoch 80: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0059 - iou: 0.6228 - val_loss: 0.0042 - val_iou: 0.6958
# Epoch 81/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0068 - iou: 0.6125
# Epoch 81: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0067 - iou: 0.6193 - val_loss: 0.0042 - val_iou: 0.7047
# Epoch 82/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0063 - iou: 0.6116
# Epoch 82: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0063 - iou: 0.6173 - val_loss: 0.0051 - val_iou: 0.6681
# Epoch 83/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0062 - iou: 0.6271
# Epoch 83: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0061 - iou: 0.6269 - val_loss: 0.0048 - val_iou: 0.6782
# Epoch 84/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0058 - iou: 0.6447
# Epoch 84: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0058 - iou: 0.6211 - val_loss: 0.0067 - val_iou: 0.6086
# Epoch 85/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0059 - iou: 0.6178
# Epoch 85: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0061 - iou: 0.6093 - val_loss: 0.0072 - val_iou: 0.6117
# Epoch 86/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0060 - iou: 0.6447
# Epoch 86: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0060 - iou: 0.6204 - val_loss: 0.0067 - val_iou: 0.6123
# Epoch 87/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0073 - iou: 0.5952
# Epoch 87: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0075 - iou: 0.5898 - val_loss: 0.0090 - val_iou: 0.5503
# Epoch 88/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0075 - iou: 0.5785
# Epoch 88: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0076 - iou: 0.5831 - val_loss: 0.0052 - val_iou: 0.6576
# Epoch 89/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0064 - iou: 0.5968
# Epoch 89: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0064 - iou: 0.5950 - val_loss: 0.0045 - val_iou: 0.6892
# Epoch 90/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0057 - iou: 0.6303
# Epoch 90: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0060 - iou: 0.6222 - val_loss: 0.0049 - val_iou: 0.6780
# Epoch 91/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0052 - iou: 0.6571
# Epoch 91: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0055 - iou: 0.6259 - val_loss: 0.0058 - val_iou: 0.6553
# Epoch 92/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0063 - iou: 0.6220
# Epoch 92: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0062 - iou: 0.6283 - val_loss: 0.0054 - val_iou: 0.6617
# Epoch 93/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0054 - iou: 0.6425
# Epoch 93: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - iou: 0.6412 - val_loss: 0.0041 - val_iou: 0.7102
# Epoch 94/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0053 - iou: 0.6591
# Epoch 94: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0052 - iou: 0.6579 - val_loss: 0.0046 - val_iou: 0.6935
# Epoch 95/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0054 - iou: 0.6460
# Epoch 95: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0055 - iou: 0.6417 - val_loss: 0.0043 - val_iou: 0.7117
# Epoch 96/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0055 - iou: 0.6479
# Epoch 96: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - iou: 0.6565 - val_loss: 0.0052 - val_iou: 0.6755
# Epoch 97/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0057 - iou: 0.6513
# Epoch 97: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0057 - iou: 0.6491 - val_loss: 0.0041 - val_iou: 0.7202
# Epoch 98/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0069 - iou: 0.6241
# Epoch 98: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0075 - iou: 0.6102 - val_loss: 0.0046 - val_iou: 0.6989
# Epoch 99/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0063 - iou: 0.6233
# Epoch 99: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0063 - iou: 0.6249 - val_loss: 0.0044 - val_iou: 0.6872
# Epoch 100/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0055 - iou: 0.6339
# Epoch 100: val_loss did not improve from 0.00405
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - iou: 0.6303 - val_loss: 0.0052 - val_iou: 0.6756

# %%
# test_iou = unet_model.evaluate(x_test, y_test, verbose=1)
# print('IoU on the test set:', test_iou[1])

test_iou = model.evaluate(x_test, y_test, verbose=1)
print('IoU on the test set:', test_iou[1])
# Out:
# WARNING:tensorflow:5 out of the last 208 calls to <function Model.make_test_function.<locals>.test_function at 0x7a7f22e7c430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0060 - iou: 0.5496
# IoU on the test set: 0.5496435165405273

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()

# Build the title with model details
descriptive_title = f'{model_name}_{metric_name}_BS{batch_size}_Epochs{epochs}_TraingValidation.png'

# Save the figure
# plt.savefig(f'/content/drive/MyDrive/MDHDS/Capstone/Cato_A/result/{descriptive_title}')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
# test_loss, test_accuracy = unet_model.evaluate(x_test, y_test)
# print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0060 - iou: 0.5496
# Test Loss: 0.006041872780770063, Test Accuracy: 0.5496435165405273

# %% [markdown]
# # Display the result

# %%
import numpy as np
import matplotlib.pyplot as plt

# # Model and training details
# model_name = "U-Net"
# metric_name = "IoU"
# batch_size = 1  # Assuming you used this batch size for training
# epochs = 100      # Assuming you trained for this many epochs

# Predict on test set
# predictions = unet_model.predict(x_test)
predictions = model.predict(x_test)

# Calculate individual IoU for a few samples
for i in range(4):  # Just the first 4 examples
    true_mask = y_test[i]
    predicted_mask = predictions[i]
    current_iou = iou(np.expand_dims(true_mask, 0), np.expand_dims(predicted_mask, 0))

    plt.figure(figsize=(12, 6))
    plt.subplot(131)
    plt.title(f'True Mask - Example {i+1}')
    plt.imshow(true_mask, cmap='gray')
    plt.subplot(132)
    plt.title(f'Predicted Mask - Example {i+1}')
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.subplot(133)
    plt.title(f'Overlay - IoU: {current_iou:.4f}')
    plt.imshow(true_mask, cmap='gray', interpolation='none')
    plt.imshow(predicted_mask.squeeze(), alpha=0.5, cmap='hot', interpolation='none')

    # Build the title with model details
    descriptive_title = f'{model_name}_{metric_name}_BS{batch_size}_Epochs{epochs}_Sample{i+1}.png'

    # Save the figure
    # plt.savefig(f'/content/drive/MyDrive/MDHDS/Capstone/Cato_A/result/{descriptive_title}')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
# # Check of masks
# print(true_masks.shape)
# print(predicted_masks.shape)
# print(true_mask_binary.shape)
# print(predicted_mask_binary.shape)

# %%
# from tensorflow.keras import backend as K

# # This resets the Keras backend, effectively clearing all model-related memory.
# K.clear_session()
